# %% [markdown]
# # kNN classifier
# ## Intuition

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot([0, 0.05, -0.05, 0.05, 0.05], [0,0.1,0.05, 0.1, 0.1],  'ro')
plt.plot([1,1.05,1.05, 1.1, 1.1], [1, 1.05, 0.95, 1.1, 1.05], 'g^')
plt.plot([0.6], [0.8], 'bs')

plt.grid(True)

plt.show()

# %% [markdown]
# ## Decision boundaries

# %%
plt.plot([2], [0],  'ms')
plt.plot([5], [0],  'gs')
plt.plot([2], [3],  'ys')
plt.plot([6], [4],  'bs')
plt.plot([3, 4.5, 3.3], [6.8, 3, 1.3], 'o', markeredgecolor='b', markerfacecolor='None' )
plt.axis([0, 8, -1, 7])
plt.grid(True)
plt.show()

# %%
plt.plot([2], [0],  'ms')
plt.plot([5], [0],  'gs')
plt.plot([2], [3],  'ys')
plt.plot([6], [4],  'bs')
plt.plot([0, 3.5], [1.5, 1.5], 'r--')
plt.plot([3.5, 3.5], [-1, 1.5], 'r--')
plt.plot([3.5, 4.3], [1.5, 2.3], 'r--')
plt.plot([3.125, 4.3], [7, 2.3], 'r--')
plt.plot([4.3, 8], [2.3, 1.666], 'r--')
plt.grid(True)
plt.show()

# %%
plt.plot([2], [0],  'ms')
plt.plot([5], [0],  'gs')
plt.plot([2], [3],  'ys')
plt.plot([6], [4],  'bs')
plt.plot([3, 4.5, 3.3], [6.8, 3, 1.3], 'o', markeredgecolor='b', markerfacecolor='None' )
plt.axis([0, 8, -1, 7])
plt.plot([0, 3.5], [1.5, 1.5], 'r--')
plt.plot([3.5, 3.5], [-1, 1.5], 'r--')
plt.plot([3.5, 4.3], [1.5, 2.3], 'r--')
plt.plot([3.125, 4.3], [7, 2.3], 'r--')
plt.plot([4.3, 8], [2.3, 1.666], 'r--')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Check - scikit-learn

# %%
from sklearn.neighbors import NearestNeighbors
import pandas as pd
samples = [[2,0], [5,0], [2,3], [6,4]]
points = [[3, 6.8], [4.5, 3], [ 3.3, 1.3]]

for metric in ['euclidean', 'manhattan', 'chebyshev']:    
    neigh = NearestNeighbors(n_neighbors=1, metric=metric)
    neigh.fit(samples) 
    dists, nn = neigh.kneighbors(points) 
    res = pd.DataFrame(np.column_stack((dists, nn)))
    res.columns = ['Distance', 'NN']
    res['NN'] = res['NN'].apply(lambda n: (samples[int(n)][0], samples[int(n)][1]))
    res['Point'] = points
    cols = res.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    res = res[cols]
    print('Metric: ', metric)
    print(res)
    print()
# Out:
# Metric:  euclidean
#         Point  Distance      NN
# 0    [3, 6.8]  3.929377  (2, 3)
# 1    [4.5, 3]  1.802776  (6, 4)
# 2  [3.3, 1.3]  1.838478  (2, 0)
#
# Metric:  manhattan
#         Point  Distance      NN
# 0    [3, 6.8]       4.8  (2, 3)
# 1    [4.5, 3]       2.5  (2, 3)
# 2  [3.3, 1.3]       2.6  (2, 0)
#
# Metric:  chebyshev
#         Point  Distance      NN
# 0    [3, 6.8]       3.0  (6, 4)
# 1    [4.5, 3]       1.5  (6, 4)
# 2  [3.3, 1.3]       1.3  (2, 0)

# %% [markdown]
# ## Yet another example

# %%
plt.plot([1, 1.1, 0.95, 1.1, 1.05], [0,0.1,0.05, 0.1, 0.1],  'ro')
plt.plot([1,1.1,1.05, 1.1, 1.1], [1, 1.1, 0.95, 1.1, 1.05], 'g^')
plt.axis([0, 1.2, -0.1, 1.2])
plt.grid(True)
plt.xlabel('HACK')
plt.ylabel('COMPUTER')
plt.show()

# %%
plt.plot([1, 1.05, 0.95, 1.05, 1.05], [0,0.1,0.05, 0.1, 0.1],  'ro')
plt.plot([1,1.05,1.05, 1.1, 1.1], [1, 1.05, 0.95, 1.1, 1.05], 'g^')
plt.plot([0.45], [0.45], 'bs')
plt.axis([0, 1.2, -0.1, 1.2])
plt.plot([0,1.2], [0.5, 0.5], 'r--')
plt.grid(True)
plt.xlabel('HACK')
plt.ylabel('COMPUTER')
plt.show()

# %%
plt.plot([1, 1.05, 0.95, 1.05, 1.05], [0,0.1,0.05, 0.1, 0.1],  'ro')
plt.plot([1,1.05,1.05, 1.1, 1.1], [1, 1.05, 0.95, 1.1, 1.05], 'g^')
plt.plot([0.45], [0.45], 'bs')
plt.axis([0, 1.2, -0.1, 1.2])
plt.plot([0,1.2], [0.5, 0.5], 'r--')
plt.arrow(0, 0, 0.40, 0.40, head_width=0.05, head_length=0.05, fc='k', ec='k')
plt.arrow(0, 0, 1, 0.9, head_width=0.05, head_length=0.05, fc='k', ec='k')
plt.arrow(0, 0, 0.90, 0.05, head_width=0.05, head_length=0.05, fc='k', ec='k')
plt.grid(True)
plt.xlabel('HACK')
plt.ylabel('COMPUTER')
plt.show()

# %% [markdown]
# ## Nearest Neighbors Classification

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors = 15

# import some data to play with
iris = datasets.load_iris()

# we only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

for metric in ['euclidean', 'manhattan', 'chebyshev']:
    
    for weights in ['uniform', 'distance']:
        # we create an instance of Neighbours Classifier and fit the data.
        clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights, metric=metric)
        clf.fit(X, y)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max]x[y_min, y_max].
        x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
        y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                             np.arange(y_min, y_max, h))
        Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        plt.figure()
        plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

        # Plot also the training points
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                    edgecolor='k', s=20)
        plt.xlim(xx.min(), xx.max())
        plt.ylim(yy.min(), yy.max())
        plt.title("Metric - %s (k = %i, weights = '%s')"
                  % (metric, n_neighbors, weights))
        

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# ## Mean distance

# %%
one_color_points = 700
mean1 = [0, 0]
cov1 = [[1, 0], [0, 1]]  # diagonal covariance
x1, y1 = np.random.multivariate_normal(mean1, cov1, one_color_points).T
mean2 = [3, 3]
cov2 = [[1, 0], [0, 1]]  # diagonal covariance
x2, y2 = np.random.multivariate_normal(mean2, cov2, one_color_points).T
mean3 = [4, 0]
cov3 = [[1, 0], [0, 1]]  # diagonal covariance
x3, y3 = np.random.multivariate_normal(mean3, cov3, one_color_points).T

n = 5
points_x = np.random.choice(500, size=(n, 1))/100
points_y = np.random.choice(400, size=(n, 1))/100

plt.figure(figsize=(10,10))
plt.plot(x1, y1, 'bx')
plt.plot(x2, y2, 'yx')
plt.plot(x3, y3, 'gx')
plt.plot(points_x, points_y, 'ro')
plt.axis('equal')



plt.grid(True)

plt.show()

# %%
x = np.array(points_x)
y = np.array(points_y)
points = np.column_stack((x, y))

data1 = np.column_stack((x1, y1))
data2 = np.column_stack((x2, y2))
data3 = np.column_stack((x3, y3))

samples = np.concatenate((data1, data2))
samples = np.concatenate((samples, data3))
print(samples.shape)
n_neighbors = 100
neigh = NearestNeighbors(n_neighbors=n_neighbors, metric='euclidean')
neigh.fit(samples) 
dists, nn = neigh.kneighbors(points) 

radius = []
for d in dists:
    radius.append(max(d))

print(radius)
r_mean = np.mean(radius)
print(r_mean)
r_mean_10 = r_mean / 10
print(r_mean_10)
# Out:
# (2100, 2)
# [0.57614473086084694, 0.58423005460952404, 0.83998003682932754, 0.51127865113630611, 0.90590823566506307]
# 0.68350834182
# 0.068350834182

# %%
import matplotlib as mpl

plt.figure(figsize=(10,10))
plt.plot(x1, y1, 'bx')
plt.plot(x2, y2, 'yx')
plt.plot(x3, y3, 'gx')
plt.plot(points_x, points_y, 'ro')
plt.axis('equal')

for i in range(n):
    circle1=plt.Circle(points[i],radius[i],color='y', alpha=.5)
    plt.gcf().gca().add_artist(circle1)


plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(x1, y1, 'bx')
plt.plot(x2, y2, 'yx')
plt.plot(x3, y3, 'gx')
plt.plot(points_x, points_y, 'ro')
plt.axis('equal')

for i in range(n):
    circle1=plt.Circle(points[i],r_mean,color='y', alpha=.5)
    plt.gcf().gca().add_artist(circle1)


plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(x1, y1, 'bx')
plt.plot(x2, y2, 'yx')
plt.plot(x3, y3, 'gx')
plt.plot(points_x, points_y, 'ro')
plt.axis('equal')

for i in range(n):
    circle1=plt.Circle(points[i],r_mean_10,color='m')
    plt.gcf().gca().add_artist(circle1)


plt.grid(True)

plt.show()

# %%
print(points)
# Out:
# [[ 3.2   2.55]
#  [ 4.04  0.64]
#  [ 4.68  1.29]
#  [ 2.67  2.97]
#  [ 0.37  1.41]]

# %%
print(samples)
print(samples.shape)
# Out:
# [[ 0.44975135  1.45418471]
#  [-0.08721128  0.39653276]
#  [-0.49760904 -1.48167013]
#  ...,
#  [ 2.72620169 -1.48662927]
#  [ 3.6886984   0.02557259]
#  [ 5.43350217 -2.24229979]]
# (2100, 2)

# %%
clf_1 = neighbors.KNeighborsClassifier(n_neighbors, metric='euclidean')
clf_1.fit(points, y)
# Out:
# /home/dom/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-abf3222b7233> in <module>()
#       1 clf_1 = neighbors.KNeighborsClassifier(n_neighbors, metric='euclidean')
# ----> 2 clf_1.fit(points, y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     777             self.outputs_2d_ = True
#     778
# --> 779         check_classification_targets(y)
#     780         self.classes_ = []
#     781         self._y = np.empty(y.shape, dtype=np.int)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'
